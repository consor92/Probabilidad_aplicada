# %% [markdown]
# <a href="https://colab.research.google.com/github/consor92/Probabilidad_aplicada/blob/Clase_Init_R/Empezando_Pruebas_con_R.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
var <- c(3,3,2,1)

# %% [markdown]
# Esta es una celda de texto...

# %%
print("Bienvenidos")

# %% [markdown]
# Definimos una variable...

# %%
a<-3
a

# %% [markdown]
# Vamos a explorar el data frame iris (de R base)

# %%
datos<-iris
class(datos)
class(a)
datos

# %%
mean(datos$Petal.Length)

# %% [markdown]
# Varianza: $\sigma^2$
#
# Desvío estándar: $\sigma$ sd()

# %%
sd(datos$Petal.Length)

# %%
desvio<-sd(datos$Petal.Length)
desvio

# %%
varianza<-desvio*desvio
varianza
